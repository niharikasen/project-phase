# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
 df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# # EXPLORATORY DATA  ANALYSIS(EDA)

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# ###### this data set contain 158 rows and 12 columns.out of which 1 is target variable and remaining 11 is independent variables.

# %%
#checking column details  of data set
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# list of column
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
#checking data types of column
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# ###### there are three  different type of data  present in data set  (object ,float64,int64)

# %%
# checking nun values if any value is present
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ###### there is no null value present in  any column

# %%
# find out the more information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# using  visualize techinque  heatmap 
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ###### There is no missing data present

# %%
# checking the value counts of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
# used describe method its give information about the numerical column
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# ###### the summary of data set look perfect sinces there is no negative values and invalid values present
# The count of all the columns are same which means there are no missing values present in the data set. The mean value is not greater then the meadian(50%)in all columns which means data is not sknewed to right in all  these column
# In the data we can observe there is huge difference in (75%) and max column in Happiness rank  and generosity column .Hence there are outlier present in the data.

# %% [markdown]
# # Data visualization

# %% [markdown]
# ######  Univariate Analysis

# %%
# create kernel density plot
happiness_score = df['Happiness Score']
sns.kdeplot(happiness_score,shade= True,color ='skyblue')
plt.xlabel('Happiness Score')
plt.ylabel('Density')
plt.title('kernel Density plot of Happiness Score')
plt.show()

# %%
# visualize count of the target variable
ax = sns.countplot(x ='Region',data =df)
print(df['Region'].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
ax = sns.countplot(x ='Happiness Score',data =df)

# %% [markdown]
# # Corrleation Between Target Variable And Independent Variable

# %%
cor =df.corr()
cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %% [markdown]
# # Headmap

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(),linewidths = 0.1,fmt = ".1g", linecolor="black",annot = True,cmap ="YlGnBu")
plt.yticks(rotation =0);
plt.show()

# %% [markdown]
# ###### heatmap show correlation matrix by visualazing the data .We can observe the relation between feature to feature and feature to label.

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(data = df,palette ="Dark2")

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le =LabelEncoder()
df['Region']=le.fit_transform(df['Region'])
df['Country']=le.fit_transform(df['Country'])
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      135       9               1            7.587                   1.39651
# 1       58       9               2            7.561                   1.30232
# 2       37       9               3            7.527                   1.32548
# 3      105       9               4            7.522                   1.45900
# 4       24       5               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %% [markdown]
# # Find Outlier Used Box plot

# %%
for i in df.columns:
    df[[i]].boxplot()
    plt.show()

# %% [markdown]
# ###### outlier present in  trust(government corruption ),standard error and family column

# %%
##remove unnecessary column like standard Error column
df = df.drop(columns=['Standard Error'], axis=1)

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
# remove ouliers 
from scipy import stats
z_threshold =3
z_scores = stats.zscore(df.select_dtypes(include ='number'))
outliers = ( z_scores >z_threshold).any(axis =1)
cleaned_data = df[~outliers]
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %% [markdown]
# # Separting Features and Label

# %%
 x = df.drop("Happiness Score",axis =1)
y = df["Happiness Score"]

# %%
print("independent variable")
x
# Out:
# independent variable
#      Country  Region  Happiness Rank  Economy (GDP per Capita)   Family  \
# 0        135       9               1                   1.39651  1.34951
# 1         58       9               2                   1.30232  1.40223
# 2         37       9               3                   1.32548  1.36058
# 3        105       9               4                   1.45900  1.33095
# 4         24       5               5                   1.32629  1.32261
# ..       ...     ...             ...                       ...      ...
# 153      118       8             154                   0.22208  0.77370
# 154       13       8             155                   0.28665  0.35386
# 155      136       4             156                   0.66320  0.47489
# 156       21       8             157                   0.01530  0.41587
# 157      141       8             158                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
print("dependent variable")
y
# Out:
# dependent variable
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %% [markdown]
# # Feature Scaling Using Standard Scalarization¶

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
print(x)
# Out:
#       Country    Region  Happiness Rank  Economy (GDP per Capita)    Family  \
# 0    1.238770  1.300256       -1.721000                  1.369621  1.320281
# 1   -0.449465  1.300256       -1.699075                  1.135226  1.514458
# 2   -0.909893  1.300256       -1.677149                  1.192861  1.361054
# 3    0.581016  1.300256       -1.655224                  1.525130  1.251922
# 4   -1.194920 -0.040302       -1.633299                  1.194876  1.221204
# ..        ...       ...             ...                       ...       ...
# 153  0.866043  0.965117        1.633576                 -1.552987 -0.800520
# 154 -1.436096  0.965117        1.655501                 -1.392303 -2.346860
# 155  1.260695 -0.375441        1.677427                 -0.455245 -1.901086
# 156 -1.260695  0.965117        1.699352                 -2.067566 -2.118467
# 157  1.370321  0.965117        1.721277                 -1.586334 -3.134725
#
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from  sklearn.metrics import mean_absolute_error
from sklearn .metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRS =0
for i in range (1,5):
    x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.3,random_state =42)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred =lr.predict(x_test)
    acc= r2_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Maximum  r2 sscore  is",maxAccu," on random_state",maxRS)
# Out:
# Maximum  r2 sscore  is 0  on random_state 1
# Maximum  r2 sscore  is 0  on random_state 2
# Maximum  r2 sscore  is 0  on random_state 3
# Maximum  r2 sscore  is 0  on random_state 4

# %%
 x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.3,random_state =42)

# %%
from sklearn.linear_model import LinearRegression
from  sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from  sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# # Linear Regression

# %%
LR =LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_test,pred_LR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_LR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.9999999425394757
# R2_score on training Data: 99.99999425394756
# Mean absolute Error:- 0.00023743398347008302
# Mean squared Error:- 0.00023743398347008302
# Root Mean squared  Error:- 0.00027656930998324415

# %% [markdown]
# ###### The r2 score value of Linear Regression model for train and test data is 100% both are same.

# %%
plt.figure(figsize = (10,6))
plt.scatter(x= pred_LR, y = y_test,color ='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize =15)
plt.ylabel('Predicted',fontsize =15)
plt.title("Linear Regression",fontsize =20)
plt.show()

# %% [markdown]
# # Random Forest Regressor

# %%
RFR = RandomForestRegressor()

RFR.fit(x_train,y_train)
pred_RFR = LR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_test,pred_RFR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_RFR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9999999425394757
# R2_score on training Data: 99.99999425394756
# Mean absolute Error:- 0.00023743398347008302
# Mean squared Error:- 0.00023743398347008302
# Root Mean squared  Error:- 0.00027656930998324415

# %% [markdown]
# ###### The r2 score value of Randonm Forest Regressor  model for train and test data is 100% both are same.

# %% [markdown]
# # K-Nearest Neighbor

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_test,pred_knn)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_knn))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: 0.954766293053678
# R2_score on training Data: 95.4766293053678
# Mean absolute Error:- 0.1769166666666667
# Mean squared Error:- 0.1769166666666667
# Root Mean squared  Error:- 0.2453862839144302

# %% [markdown]
# ###### The r2 score value of KNN model for train and test data is 95% both are same.

# %% [markdown]
# # Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:',r2_score(y_test,pred_dtr)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_dtr))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_dtr))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: 0.9947221519806411
# R2_score on training Data: 99.4722151980641
# Mean absolute Error:- 0.05983333333333332
# Mean squared Error:- 0.05983333333333332
# Root Mean squared  Error:- 0.08381999562554673

# %% [markdown]
# ###### in this model mean squared and mean squred error then the previous two model.

# %% [markdown]
# # # ExtraTrees Regressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR = etr.predict(x_test)
pred_train = etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on training Data:',r2_score(y_test,pred_ETR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_ETR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_ETR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: 0.997026659804968
# R2_score on training Data: 99.70266598049679
# Mean absolute Error:- 0.03096520833333379
# Mean squared Error:- 0.03096520833333379
# Root Mean squared  Error:- 0.06291315931173158

# %% [markdown]
# ###### The r2 score value of Extra tree regressor  model for train and test data is 99% both are same. and in this model mean squared and mean squred error are less then  the previous  model.

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking crosss validation score for Linear Regression
score = cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_LR)-score.mean()*100))
# Out:
# [0.99999948 0.99999846 0.99999837 0.99999564 0.99999934]
# 0.9999982590509703
# Difference Between Accuracy and Cross Validation Score is_ -98.99982596255755

# %%
# checking crosss validation score for random forest regressor
score = cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_RFR)-score.mean()*100))
# Out:
# [-3.8384824  -0.65972472 -0.50049295 -0.8133477  -2.25049217]
# -1.612507986364313
# Difference Between Accuracy and Cross Validation Score is_ 162.2507985789708

# %%
# checking crosss validation score for knn
score = cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_knn)-score.mean()*100))
# Out:
# [-9.02932695 -1.7730542  -1.55087469 -6.93909684 -4.02904402]
# -4.664279340065793
# Difference Between Accuracy and Cross Validation Score is_ 467.382700299633

# %%
# checking crosss validation score for Decision Tree regressor
score = cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_dtr)-score.mean()*100))
# Out:
# [-3.0408101  -0.43409528 -0.36465796 -0.89177481 -2.0950056 ]
# -1.3652687496691827
# Difference Between Accuracy and Cross Validation Score is_ 137.5215971188989

# %%
# checking crosss validation score for Extra tree Regressor
score = cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_ETR)-score.mean()*100))
# Out:
# [-3.62807906  0.75385765  0.9609555   0.95608206 -2.136258  ]
# -0.6186883704167501
# Difference Between Accuracy and Cross Validation Score is_ 62.865863701479974

# %% [markdown]
# ###### The Linear regression  and Random Forest Regressor  give us good r2 value.
# Random Forest regressor our best fitting and best performing model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_features':['auto','sqrt','log2'],
               'random_state':[10,50,500],
             'max_depth':[None,10,20,30],
             'min_samples_split':[2,5,10],
             'n_estimators':[25,50,100,200]}

# %%
GCV =GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [25, 50, 100, 200],
#                          'random_state': [10, 50, 500]})

# %%
GCV.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_split': 2,
#  'n_estimators': 25,
#  'random_state': 50}

# %%
Final_model = RandomForestRegressor(max_features ='auto', max_depth =None, n_estimators=25, min_samples_split = 2,random_state= 50)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)

# %% [markdown]
# # Saving The Model¶

# %%
import joblib
joblib.dump(Final_model,"World Happiness.pkl")
# Out:
# ['World Happiness.pkl']

# %% [markdown]
# # Predicting The Save Model

# %%
# lets load the save model and predict it 

model =joblib.load("World Happiness.pkl")
prediction = model.predict(x_test)
prediction
# Out:
# array([4.27216, 5.98808, 4.1036 , 3.24732, 5.12232, 6.60212, 4.89276,
#        4.8744 , 4.94156, 3.75244, 6.9318 , 5.83276, 7.05532, 5.54708,
#        6.85448, 6.54608, 4.51348, 4.67224, 5.0018 , 5.71944, 3.68868,
#        6.9886 , 7.31476, 7.3406 , 6.43336, 5.16924, 5.89132, 3.91688,
#        4.42872, 3.65968, 3.65484, 5.35204, 3.98448, 5.83708, 4.35468,
#        5.18264, 3.402  , 6.1224 , 5.66448, 4.54352, 6.71232, 4.05836,
#        5.27804, 3.61016, 6.33168, 5.28504, 6.94004, 4.22836])

# %%
a = np.array(y_test)
df = pd.DataFrame()
df["predicted"] = prediction
df["original"] = a
df
# Out:
#     predicted  original
# 0     4.27216     4.307
# 1     5.98808     5.987
# 2     4.10360     4.194
# 3     3.24732     2.905
# 4     5.12232     5.057
# 5     6.60212     6.574
# 6     4.89276     4.898
# 7     4.87440     4.876
# 8     4.94156     4.949
# 9     3.75244     3.931
# 10    6.93180     6.901
# 11    5.83276     5.828
# 12    7.05532     6.983
# 13    5.54708     5.548
# 14    6.85448     6.786
# 15    6.54608     6.505
# 16    4.51348     4.507
# 17    4.67224     4.686
# 18    5.00180     4.971
# 19    5.71944     5.695
# 20    3.68868     3.655
# 21    6.98860     6.937
# 22    7.31476     7.200
# 23    7.34060     7.284
# 24    6.43336     6.485
# 25    5.16924     5.192
# 26    5.89132     5.889
# 27    3.91688     3.956
# 28    4.42872     4.369
# 29    3.65968     3.681
# 30    3.65484     3.781
# 31    5.35204     5.332
# 32    3.98448     3.995
# 33    5.83708     5.833
# 34    4.35468     4.350
# 35    5.18264     5.129
# 36    3.40200     3.340
# ...

# %% [markdown]
# ###### Here the original value and predicted value is same means prediction is correct and if it is not same then prediction is wrong.
