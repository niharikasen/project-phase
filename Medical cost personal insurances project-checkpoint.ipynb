# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Medical%20Cost%20Insurance/medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(15)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.tail(30)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1309   41    male  32.200         2     no  southwest   6875.96100
# 1310   42    male  26.315         1     no  northwest   6940.90985
# 1311   33  female  26.695         0     no  northwest   4571.41305
# 1312   34    male  42.900         1     no  southwest   4536.25900
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1316   19  female  20.600         0     no  southwest   1731.67700
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1318   35    male  39.710         4     no  northeast  19496.71917
# 1319   39  female  26.315         2     no  northwest   7201.70085
# 1320   31    male  31.065         3     no  northwest   5425.02335
# ...

# %% [markdown]
# ######  In this data set three categorical column present .

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ###### This data set contain 1338 rows and 7 columns.out of which 1 is target variable and remaining 6 is independent variable.

# %%
#checking column details  of data set
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# list of column
df.columns.tolist()
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
#checking data types of column
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# ###### there are three  different type of data  present in data set  (float64,int64,object)

# %%
# checking nun values if any value is present
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ###### there is no null value present in  any column

# %%
# find out the more information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# using  visualize techinque  heatmap 
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ###### There is no missing data present

# %%
# we check unique value in charges  collumn 
df['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
df['charges'].nunique()
# Out:
# 1337

# %%
# checking the value counts of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %% [markdown]
# # Converting categoical Features to Numerical

# %%
convert_data ={'sex':{'female':1,'male':0},
              'smoker':{'no':0,'yes':1},
                'region':{'northwest':0,'northeast':1,'southwest':2,'southeast':3}
              }
df1= df.copy()
df1.replace(convert_data,inplace = True)

# %% [markdown]
# # Description of Data set

# %%
# used describe method its give information about the numerical column
df1.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.544096  13270.422265
# std       1.130888  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       3.000000  16639.912515
# max       3.000000  63770.428010

# %% [markdown]
# ###### the  summary of data set look perfect sinces there is no negative values and invalid values present

# %% [markdown]
# ###### from above the description we can observer the following.

# %% [markdown]
# #
# The count of all the columns are same  which means there are no missing values present in the data set.
# The mean value is  not greater then the meadian(50%)in age, bmi and children  columns which means data is  not sknewed to right in these column
#  In the  data we can observe there is huge difference in (75%) and max column in age and  bmi  column .Hence there are outlier present in the data.

# %% [markdown]
# # Data visualization

# %% [markdown]
# ######  Univariate Analysis
# In univariate analysis means  we are performing the analysis on a single column.

# %%
# visualize count of the target variable
ax = sns.countplot(x ='charges',data =df)
print(df1['charges'].value_counts())
# Out:
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
#plot a bar plot each column  against the target variable.target variable is Charges.
plt.figure(figsize =(10,6))
plt.title('Age vs charges')
sns.barplot(x ='age', y='charges',data = df1 ,palette ='Set1')
# Out:
# <Axes: title={'center': 'Age vs charges'}, xlabel='age', ylabel='charges'>

# %%
#plot a bar plot each column  against the target variable.target variable is Charges.
plt.figure(figsize =(10,6))
plt.title('Sex vs charges')
sns.barplot(x ='sex', y='charges',data = df1 ,palette ='Set1')
# Out:
# <Axes: title={'center': 'Sex vs charges'}, xlabel='sex', ylabel='charges'>

# %%
#plot a bar plot each column  against the target variable.target variable is Charges.
plt.figure(figsize =(10,6))
plt.title('Bmi vs charges')
sns.barplot(x ='bmi', y='charges',data = df1 ,palette ='Set1')
# Out:
# <Axes: title={'center': 'Bmi vs charges'}, xlabel='bmi', ylabel='charges'>

# %%
#plot a bar plot each column  against the target variable.target variable is Charges.
plt.figure(figsize =(10,6))
plt.title('Childrean vs charges')
sns.barplot(x ='children', y='charges',data = df1 ,palette ='Set1')
# Out:
# <Axes: title={'center': 'Childrean vs charges'}, xlabel='children', ylabel='charges'>

# %%
#plot a bar plot each column  against the target variable.target variable is Charges.
plt.figure(figsize =(10,6))
plt.title('Smoker vs charges')
sns.barplot(x ='smoker', y='charges',data = df1 ,palette ='Set1')
# Out:
# <Axes: title={'center': 'Smoker vs charges'}, xlabel='smoker', ylabel='charges'>

# %%
#plot a bar plot each column  against the target variable.target variable is Charges.
plt.figure(figsize =(10,6))
plt.title('Region vs charges')
sns.barplot(x ='region', y='charges',data = df1 ,palette ='Set1')
# Out:
# <Axes: title={'center': 'Region vs charges'}, xlabel='region', ylabel='charges'>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(data = df1,palette ="Dark2")

# %% [markdown]
# ######  The pair plot gives the pairwise relation between the feature

# %% [markdown]
# # Box plot

# %%
#plot a box plot to find outlier it better for visualization.
plt.figure(figsize =(20,50))
p = 1
for i in df1:
    if p<=14:
        plt.subplot(5,4,p)
        sns.boxplot(df1[i],palette ="Set2_r")
        plt.xlabel(i)
        p+=1
        
        plt.show()

# %% [markdown]
# ###### the outlier present in bmi column and charges column.

# %% [markdown]
# ###### Here we treat outlier in bmi column

# %%
Q1 =df1['bmi'].quantile(0.25)
Q2=df1['bmi'].quantile(0.50)
Q3 =df1['bmi'].quantile(0.75)
iqr =Q3-Q1
lowerlim =Q1-1.5*iqr
upplim = Q3-1.5*iqr
print(lowerlim)
print(upplim)
# Out:
# 13.7
# 22.0975

# %% [markdown]
# # check how data is distributed in each column

# %%
#plot a box plot to find outlier it better for visualization.
plt.figure(figsize =(20,25),facecolor = "green")

plotnumber = 1
for column in df1:
    if plotnumber<=16:
        
        ax = plt.subplot(6,4,plotnumber)
        
        sns.distplot(df1[column],color ="b")
        
        plt.xlabel(column,fontsize=20)
        
        plotnumber+=1
        
        
        plt.show()

# %% [markdown]
# ###### From above distribution plots we can notice that the data almost look normal in all column except charges  and smoker column.

# %%
#checking skewness
df1.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.048975
# charges     0.116171
# dtype: float64

# %%
df1['charges'] =np.cbrt(df1['charges'])

# %%
df1.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.048975
# charges    -0.021036
# dtype: float64

# %%
df1['smoker'] =np.cbrt(df1['smoker'])

# %%
df1.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.048975
# charges    -0.021036
# dtype: float64

# %% [markdown]
# # Corrleation  Between Target Variable And Independent Variable

# %%
cor =df1.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.109272  0.042469 -0.025019 -0.005212  0.299008
# sex       0.020856  1.000000 -0.046371 -0.017163 -0.076185 -0.016121 -0.057292
# bmi       0.109272 -0.046371  1.000000  0.012759  0.003750  0.261829  0.198341
# children  0.042469 -0.017163  0.012759  1.000000  0.007673 -0.019257  0.067998
# smoker   -0.025019 -0.076185  0.003750  0.007673  1.000000  0.053930  0.787251
# region   -0.005212 -0.016121  0.261829 -0.019257  0.053930  1.000000  0.056993
# charges   0.299008 -0.057292  0.198341  0.067998  0.787251  0.056993  1.000000

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df1.corr(),linewidths = 0.1,fmt = ".1g", linecolor="black",annot = True,cmap ="YlGnBu")
plt.yticks(rotation =0);
plt.show()

# %% [markdown]
# ###### This heatmap show correlation matrix by visualazing the data .We can observe  the relation between feature to feature and feature to label.
# 1)  we can observe smoker column is highly correlated with label column "charges"
# 2) there is least correlation  with sex column to lable column "charges"

# %%
cor['charges'].sort_values(ascending = False)
# Out:
# charges     1.000000
# smoker      0.787251
# age         0.299008
# bmi         0.198341
# children    0.067998
# region      0.056993
# sex        -0.057292
# Name: charges, dtype: float64

# %% [markdown]
# # Visualizing  The Correlation Between Label  And Features Using Bar Plot

# %%
plt.figure(figsize = (20,15))
df.corr()['charges'].sort_values(ascending = False).drop(['charges']).plot(kind ='bar',color ="m")
plt.xlabel('Feature',fontsize =15)
plt.ylabel('Target',fontsize =15)
plt.title("Correlation between label and features using bar plot",fontsize =20)
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %%
df1.sample(5)
# Out:
#      age  sex     bmi  children  smoker  region      charges
# 268   45    0  30.200         1       0       2   7441.05300
# 611   38    1  34.800         2       0       2   6571.54400
# 302   56    1  37.510         2       0       3  12265.50690
# 616   56    1  28.595         0       0       1  11658.11505
# 426   38    1  27.265         1       0       1   6555.07035

# %%
df1['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %% [markdown]
# # Separting Features and Label

# %%
 x = df1.drop("charges",axis =1)
y = df1["charges"]

# %%
print("independent variable")
x
# Out:
# independent variable
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       2
# 1      18    0  33.770         1       0       3
# 2      28    0  33.000         3       0       3
# 3      33    0  22.705         0       0       0
# 4      32    0  28.880         0       0       0
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       0
# 1334   18    1  31.920         0       0       1
# 1335   18    1  36.850         0       0       3
# 1336   21    1  25.800         0       0       2
# 1337   61    1  29.070         0       1       0
#
# [1338 rows x 6 columns]

# %%
print("dependent variable")
y
# Out:
# dependent variable
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# # Feature Scaling Using Standard  Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
print(x)
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.438764  1.010519 -0.453320 -0.908614  1.970587  0.403289
# 1    -1.509965 -0.989591  0.509621 -0.078767 -0.507463  1.287881
# 2    -0.797954 -0.989591  0.383307  1.580926 -0.507463  1.287881
# 3    -0.441948 -0.989591 -1.305531 -0.908614 -0.507463 -1.365894
# 4    -0.513149 -0.989591 -0.292556 -0.908614 -0.507463 -1.365894
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473 -0.989591  0.050297  1.580926 -0.507463 -1.365894
# 1334 -1.509965  1.010519  0.206139 -0.908614 -0.507463 -0.481303
# 1335 -1.509965  1.010519  1.014878 -0.908614 -0.507463  1.287881
# 1336 -1.296362  1.010519 -0.797813 -0.908614 -0.507463  0.403289
# 1337  1.551686  1.010519 -0.261388 -0.908614  1.970587 -1.365894
#
# [1338 rows x 6 columns]

# %% [markdown]
# # Variance Information Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import  variance_inflation_factor
vif =pd.DataFrame()
vif["VIF value"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["features"] = x.columns
vif
# Out:
#    VIF value  features
# 0   7.646155       age
# 1   1.908346       sex
# 2  10.732618       bmi
# 3   1.798408  children
# 4   1.254743    smoker
# 5   3.089731    region

# %% [markdown]
# ###### The VIF value is not higher then 10 . so we don't need to solve the multicollinearity issues

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Finding the best random state¶

# %%
from sklearn.model_selection import train_test_split
from  sklearn.metrics import mean_absolute_error
from sklearn .metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRS =0
for i in range (1,5):
    x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =.30,random_state =0)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred =lr.predict(x_test)
    acc= r2_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Maximum  r2 sscore  is",maxAccu," on random_state",maxRS)
# Out:
# Maximum  r2 sscore  is 0  on random_state 1
# Maximum  r2 sscore  is 0  on random_state 2
# Maximum  r2 sscore  is 0  on random_state 3
# Maximum  r2 sscore  is 0  on random_state 4

# %%
x_train, x_test,y_train ,y_test = train_test_split(x , y, test_size =0.30,random_state =maxRS)

# %% [markdown]
# # Regression Alorithm

# %%
from sklearn.linear_model import LinearRegression
from  sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from  sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# # Linear Regression

# %%
LR =LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:',r2_score(y_test,pred_LR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_LR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.7907514220754801
# R2_score on training Data: 79.07514220754801
# Mean absolute Error:- 4018.0493717255913
# Mean squared Error:- 4018.0493717255913
# Root Mean squared  Error:- 5776.569812316577

# %% [markdown]
# ###### The   r2 score value of Linear Regression model  for train  and test data is 76 both are same.

# %%
plt.figure(figsize = (10,6))
plt.scatter(x= pred_LR, y = y_test,color ='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize =15)
plt.ylabel('Predicted',fontsize =15)
plt.title("Linear Regression",fontsize =20)
plt.show()

# %% [markdown]
# # Random Forest Regressor

# %%
RFR = RandomForestRegressor()

RFR.fit(x_train,y_train)
pred_RFR = LR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:',r2_score(y_test,pred_RFR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_RFR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.7648361654893695
# R2_score on training Data: 76.48361654893695
# Mean absolute Error:- 0.013971955762459694
# Mean squared Error:- 0.013971955762459694
# Root Mean squared  Error:- 0.022493555157080403

# %% [markdown]
# ###### in this model r2 score train and test data is same and  mean error of both absolute and squred also same.

# %% [markdown]
# # K-Nearest Neighbor

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:',r2_score(y_test,pred_knn)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_knn))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: 0.06967692427105066
# R2_score on training Data: 6.9676924271050655
# Mean absolute Error:- 7863.242193920398
# Mean squared Error:- 7863.242193920398
# Root Mean squared  Error:- 11367.419144318974

# %% [markdown]
# ###### in this model mean squared and mean squred error then the previous two model.

# %% [markdown]
# # Lasso

# %%
lasso = Lasso()

lasso.fit(x_train,y_train)
pred_lasso = LR.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:',r2_score(y_test,pred_lasso)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_lasso))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_lasso))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.7648361654893695
# R2_score on training Data: 76.48361654893695
# Mean absolute Error:- 0.013971955762459694
# Mean squared Error:- 0.013971955762459694
# Root Mean squared  Error:- 0.022493555157080403

# %% [markdown]
# ###### in  this model mean squared is less than knn model and r2 score test and train is also similar.

# %% [markdown]
# # Ridge

# %%
rd= Ridge()

rd.fit(x_train,y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training Data:',r2_score(y_test,pred_rd)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_rd))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_rd))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score: 0.7902874068682706
# R2_score on training Data: 79.02874068682706
# Mean absolute Error:- 4032.6235344914135
# Mean squared Error:- 4032.6235344914135
# Root Mean squared  Error:- 5782.971126805286

# %% [markdown]
# ###### in this ridge model mean squred error and root mean squred error is very high .

# %% [markdown]
# # Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:',r2_score(y_test,pred_dtr)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_dtr))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_dtr))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: 0.6991791645256451
# R2_score on training Data: 69.91791645256451
# Mean absolute Error:- 3156.2203777089553
# Mean squared Error:- 3156.2203777089553
# Root Mean squared  Error:- 6926.163276079888

# %% [markdown]
# ######  in this  model mean squred error and root mean squred error is very high as ompared to ridge model.

# %% [markdown]
# # Support Vector Regressor

# %%
svr = SVR()
svr.fit(x_train,y_train)
pred_SVR = svr.predict(x_test)
pred_train = svr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:',r2_score(y_test,pred_SVR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_SVR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_SVR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_SVR)))
# Out:
# R2_score: 0.6991791645256451
# R2_score on training Data: -8.848062171281068
# Mean absolute Error:- 8671.570494190215
# Mean squared Error:- 8671.570494190215
# Root Mean squared  Error:- 13174.954365260788

# %% [markdown]
# ###### in this model the major differences between r2 test and train data.error of root mean is also high .

# %% [markdown]
# # ExtraTrees Regressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_ETR = etr.predict(x_test)
pred_train = etr.predict(x_train)
print('R2_score:',r2_score(y_test,pred_ETR))
print('R2_score on training Data:',r2_score(y_test,pred_ETR)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred_ETR))
print('Mean squared Error:-',mean_absolute_error(y_test,pred_ETR))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# R2_score: 0.8406681074286053
# R2_score on training Data: 84.06681074286053
# Mean absolute Error:- 2869.3553826157954
# Mean squared Error:- 2869.3553826157954
# Root Mean squared  Error:- 5040.691587794297

# %% [markdown]
# ###### in this model root mean squred value is higher then the priveous model

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking crosss validation score for Linear Regression
score = cross_val_score(LR ,x,y, cv =5,scoring ='r2')
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_LR)-score.mean()*100))
# Out:
# [0.76258026 0.70682745 0.77683066 0.7319328  0.75695771]
# 0.7470257759641312
# Difference Between Accuracy and Cross Validation Score is_ -73.91182617433765

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_RFR)-score.mean()*100))
# Out:
# [0.85075511 0.70685466 0.87963528 0.82857841 0.78631943]
# 0.8104285759471477
# Difference Between Accuracy and Cross Validation Score is_ -80.2780214292254

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_knn)-score.mean()*100))
# Out:
# [0.84887744 0.6888682  0.85679367 0.81365388 0.78350921]
# 0.7983404801026706
# Difference Between Accuracy and Cross Validation Score is_ -79.05143421490676

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_lasso)-score.mean()*100))
# Out:
# [-8.22530104e-06 -4.44089210e-16 -1.36415556e-03 -1.19929520e-04
#  -5.25844771e-04]
# -0.0004036310293852541
# Difference Between Accuracy and Cross Validation Score is_ 0.80518810967911

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_rd)-score.mean()*100))
# Out:
# [0.80200197 0.68904562 0.82892966 0.7673145  0.73757877]
# 0.7649741049027494
# Difference Between Accuracy and Cross Validation Score is_ -75.73258548353436

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_dtr)-score.mean()*100))
# Out:
# [0.73897526 0.64378414 0.68011663 0.78429711 0.69827845]
# 0.7090903199689705
# Difference Between Accuracy and Cross Validation Score is_ -70.22832422520393

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_SVR)-score.mean()*100))
# Out:
# [-0.11535805 -0.1103838  -0.0799386  -0.10417827 -0.10828845]
# -0.10362943344436885
# Difference Between Accuracy and Cross Validation Score is_ 10.274462722724074

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",(r2_score(y_test,pred_ETR)-score.mean()*100))
# Out:
# [0.81376999 0.67410258 0.85590562 0.80043103 0.7717624 ]
# 0.7831943245311414
# Difference Between Accuracy and Cross Validation Score is_ -77.55276555342981

# %% [markdown]
# ###### Lasso  Regression as our best fitting and best performing model.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param ={'alpha':[1.0,0.5,.4,2],
        'fit_intercept':[True,False],
        'precompute':[True,False],
        'warm_start':[True,False],
       'random_state':[1,4,10,20]
       }
gscv = GridSearchCV(Lasso(),param,cv =5)
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.5, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'precompute': [True, False],
#                          'random_state': [1, 4, 10, 20],
#                          'warm_start': [True, False]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'precompute': True,
#  'random_state': 1,
#  'warm_start': True}

# %%
Model = Lasso(alpha = 1.0,fit_intercept =True,precompute=True,random_state =1,warm_start =True)

# %%
Model.fit(x_train,y_train)
pred = Model.predict(x_test)

print('R2_score:',r2_score(y_test,pred))
print('R2_score on training Data:',r2_score(y_test,pred)*100)
print('Mean absolute Error:-',mean_absolute_error(y_test,pred))
print('Mean squared Error:-',mean_absolute_error(y_test,pred))
print("Root Mean squared  Error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: -2.728728008261072e-05
# R2_score on training Data: -0.002728728008261072
# Mean absolute Error:- 0.03743607479296061
# Mean squared Error:- 0.03743607479296061
# Root Mean squared  Error:- 0.04638512815604665

# %%
import joblib
joblib.dump(Model," Medical cost personal insurances .pkl")
# Out:
# [' Medical cost personal insurances .pkl']

# %%
import pickle
filename = 'Medical cost personal insurances.pkl'
pickle.dump(Model,open(filename, 'wb'))

# %%
# lets load the save model and predict it 
Model =joblib.load(" Medical cost personal insurances .pkl")
prediction = Model.predict(x_test)
prediction
# Out:
# array([1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
#        1.40145962, 1.40145962, 1.40145962, 1.40145962, 1.40145962,
# ...

# %%
a = np.array(y_test)
df1 = pd.DataFrame()
df1["predicted"] = prediction
df1["original"] = a
df1
# Out:
#      predicted  original
# 0      1.40146  1.453388
# 1      1.40146  1.339939
# 2      1.40146  1.392470
# 3      1.40146  1.353766
# 4      1.40146  1.353658
# ..         ...       ...
# 397    1.40146  1.477045
# 398    1.40146  1.386398
# 399    1.40146  1.383118
# 400    1.40146  1.320839
# 401    1.40146  1.461395
#
# [402 rows x 2 columns]
