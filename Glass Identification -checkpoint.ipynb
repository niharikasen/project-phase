# %%
import pandas as pd 
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niharikasen/Niharikasen/main/Glass%20Identification%20(1).csv')
df
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0            1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213        214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %%
df.head()
# Out:
#    Id number       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0          1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#      Id number       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209        210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210        211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211        212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212        213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213        214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
#checking dimension of data set
df.shape
# Out:
# (214, 11)

# %% [markdown]
# ###### this data set contain 214 rows and 11 columns.out of which 1 is target variable and remaining 10 is independent variables.

# %%
#checking column details  of data set
df.columns
# Out:
# Index(['Id number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'Type'],
#       dtype='object')

# %%
# list of column
df.columns.tolist()
# Out:
# ['Id number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type']

# %%
#checking data types of column
df.dtypes
# Out:
# Id number      int64
# RI           float64
# Na           float64
# Mg           float64
# Al           float64
# Si           float64
# K            float64
# Ca           float64
# Ba           float64
# Fe           float64
# Type           int64
# dtype: object

# %% [markdown]
# ###### there are two different type of data present in data set (float64,int64)¶

# %%
# checking nun values if any value is present
df.isnull().sum()
# Out:
# Id number    0
# RI           0
# Na           0
# Mg           0
# Al           0
# Si           0
# K            0
# Ca           0
# Ba           0
# Fe           0
# Type         0
# dtype: int64

# %% [markdown]
# ###### there is no null value present in any column

# %%
# find out the more information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id number  214 non-null    int64
#  1   RI         214 non-null    float64
#  2   Na         214 non-null    float64
#  3   Mg         214 non-null    float64
#  4   Al         214 non-null    float64
#  5   Si         214 non-null    float64
#  6   K          214 non-null    float64
#  7   Ca         214 non-null    float64
#  8   Ba         214 non-null    float64
#  9   Fe         214 non-null    float64
#  10  Type       214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
# using  visualize techinque  heatmap 
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ###### The graph show there  is no missing data present.

# %%
# we check unique value in quality collumn 
df['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
df['Type'].nunique()
# Out:
# 6

# %%
# checking the value counts of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: Id number, Length: 214, dtype: int64
#
#
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI, Length: 178, dtype: int64
#
#
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na, Length: 142, dtype: int64
#
#
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64
#
#
# 1.54    8
# 1.19    6
# 1.43    5
# 1.29    5
# 1.23    5
#        ..
# 1.08    1
# 1.64    1
# 1.61    1
# 1.07    1
# 1.94    1
# Name: Al, Length: 118, dtype: int64
#
#
# 72.86    4
# 72.99    4
# 73.10    4
# 73.28    4
# 73.11    4
#         ..
# ...

# %% [markdown]
# # Description of Data set

# %%
# used describe method its give information about the continuous column
df.describe()
# Out:
#         Id number          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009    2.780374
# std      0.652192    1.423153    0.497219    0.097439    2.103739
# ...

# %% [markdown]
# ###### The summary of data set look perfect sinces there is no negative values and invalid values present

# %% [markdown]
# ###### from above the description we can observer the following.
# 1. The count of all the columns are same which means there are no missing values present in the data set.
#
# 2. The mean value is less  then the meadian(50%)which means data is  not sknewed to right in these  all colum.
#
# 3. In the data we can observe there is difference in (75%) and max column in Na, Ca,column .Hence there are outlier present in the data.
#
# 4. we observe the data is uniformly distributed.
#
# 5. Now that we  observer  the dataset, we know that it doesn't have any null values and all the attributes are numerical. Even the type which is categorical in nature is represented as integers.

# %% [markdown]
# # Data visualization

# %% [markdown]
# ###### Univariate Analysis
# In univariate analysis means we are performing the analysis on a single column.

# %%
sns.set(style="whitegrid", font_scale=1.8)
plt.subplots(figsize = (15,8))
sns.countplot(x ='Type',data=df).set_title('Count of Glass Types')
# Out:
# Text(0.5, 1.0, 'Count of Glass Types')

# %% [markdown]
# ###### We see that Type 2 and 1 have the highest occurences in the dataset.

# %% [markdown]
# # Boxplot

# %%
#plot a box plot each column  against the target variable.target variable is  type .
sns.boxplot( x='Type', y='RI',data = df)
# Out:
# <Axes: xlabel='Type', ylabel='RI'>

# %% [markdown]
# ######  we create box plot  RI column against  Type .  we observe some outlier present in type 2 and type 7.The box plot  also shows that average Refractive index is similar for all types

# %%
sns.boxplot( x='Type', y='Na', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Na'>

# %% [markdown]
# ###### we create box plot Na column against Type . we observe some outlier present in type 2 and type 5. sodium content is higher in Type 6 & 7,

# %%
sns.boxplot( x='Type', y='Mg', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Mg'>

# %% [markdown]
# ###### we create box plot Mg column against Type . we observe some outlier present in type 2 and type 7.Magnesium content is fairly high in Type 1, 2 & 3.

# %%
sns.boxplot( x='Type', y='Al', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Al'>

# %% [markdown]
# ######  we create box plot  AI column against  Type . Aluminium is higher in type 5 & 7.

# %%
sns.boxplot( x='Type', y='Si', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Si'>

# %% [markdown]
# ######  we create box plot  Si column against  Type . Silica does not provide much information. to differentiate as it has the highest concentration amongst all the but has similar range for all types.

# %%
sns.boxplot( x='Type', y='K', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='K'>

# %% [markdown]
# ######  we create box plot  K column against  Type . Potassium also doesn't provide much insight. But it's higher in type 5 and oulier present in type 7

# %%
sns.boxplot( x='Type', y='Ca', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Ca'>

# %% [markdown]
# ######  we create box plot  Ca column against  Type .Calcium is highest in type 5.

# %%
sns.boxplot( x='Type', y='Ba', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Ba'>

# %% [markdown]
# ###### we create box plot Ba column against Type . Barium is highest in type 7.

# %%
sns.boxplot( x='Type', y='Fe', data = df)
# Out:
# <Axes: xlabel='Type', ylabel='Fe'>

# %% [markdown]
# ###### we create box plot Fe column against Type .iron is present in   type 1, 2 & 3 have high values for some glasses than the other

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df[['RI','Na','Mg','Al','Si','Ca']], kind='reg')

# %% [markdown]
# ###### we can clearly see some strong relationship between Calcium and Refractive index. Silica and RI seem to have an inverse relationship.

# %%
sns.set(style="whitegrid", font_scale=1.3)
plt.subplots(figsize = (20,10))
plt.subplot(2,2,1)
sns.kdeplot(df["RI"], shade = True)

plt.title("RI Distribution ")

plt.subplot(2,2,2)
sns.kdeplot(df["Si"], shade = True)

plt.title("Si Distribution ")
plt.subplot(2,2,3)
sns.kdeplot(df["Mg"], shade = True)

plt.title("Mg Distribution ")

plt.subplot(2,2,4)

sns.kdeplot(df["Al"], shade = True)

plt.title("Al Distribution ")
# Out:
# Text(0.5, 1.0, 'Al Distribution ')

# %% [markdown]
# # Corrleation Between Target Variable And Independent Variable

# %%
cor =df.corr()
cor
# Out:
#            Id number        RI        Na        Mg        Al        Si  \
# Id number   1.000000 -0.072209  0.375722 -0.650328  0.490113  0.061232
# RI         -0.072209  1.000000 -0.191885 -0.122274 -0.407326 -0.542052
# Na          0.375722 -0.191885  1.000000 -0.273732  0.156794 -0.069809
# Mg         -0.650328 -0.122274 -0.273732  1.000000 -0.481799 -0.165927
# Al          0.490113 -0.407326  0.156794 -0.481799  1.000000 -0.005524
# Si          0.061232 -0.542052 -0.069809 -0.165927 -0.005524  1.000000
# K           0.003149 -0.289833 -0.266087  0.005396  0.325958 -0.193331
# Ca          0.090800  0.810403 -0.275442 -0.443750 -0.259592 -0.208732
# Ba          0.451001 -0.000386  0.326603 -0.492262  0.479404 -0.102151
# Fe         -0.072794  0.143010 -0.241346  0.083060 -0.074402 -0.094201
# Type        0.877357 -0.164237  0.502898 -0.744993  0.598829  0.151565
#
#                   K        Ca        Ba        Fe      Type
# ...

# %% [markdown]
# # Heatmap

# %%
 plt.figure(figsize = (20,15))
sns.heatmap(df.corr(),linewidths = 0.1,fmt = ".1g", linecolor="black",annot = True,cmap ="YlGnBu")
plt.yticks(rotation =0);
plt.show()

# %% [markdown]
# ###### This heatmap show correlation matrix by visualazing the data .We can observe  the relation between feature to feature and feature to label.
#  AI and Ba have intermediate correlation between each other.
# RI and Ca have strong correlation between each other.

# %%
##remove unnecessary column like id number column
df = df.drop(columns=['Id number'], axis=1)

# %% [markdown]
# # Remove outliers

# %%
from scipy import stats
z_threshold =3
z_scores = stats.zscore(df.select_dtypes(include ='number'))
outliers = ( z_scores >z_threshold).any(axis =1)
cleaned_data = df[~outliers]
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %% [markdown]
# # Visualizing  The Correlation Between Label  And Features Using Bar Plot

# %%
plt.figure(figsize = (20,15))
df.corr()['Type'].sort_values(ascending = False).drop(['Type']).plot(kind ='bar',color ="m")
plt.xlabel('Feature',fontsize =15)
plt.ylabel('Target',fontsize =15)
plt.title("Correlation between label and features using bar plot",fontsize =20)
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %%
df.sample(5)
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 19   1.51735  13.02  3.54  1.69  72.73  0.54  8.44  0.00  0.07     1
# 198  1.51531  14.38  0.00  2.66  73.10  0.04  9.08  0.64  0.00     7
# 119  1.51652  13.56  3.57  1.47  72.45  0.64  7.96  0.00  0.00     2
# 31   1.51747  12.84  3.50  1.14  73.27  0.56  8.55  0.00  0.00     1
# 208  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00     7

# %% [markdown]
# # Separating features and label

# %%
x =df.drop(['Type'], axis = 1)
y = df['Type']

# %%
print("independent variable")
x
# Out:
# independent variable
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
print("dependent variable")
y
# Out:
# dependent variable
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %% [markdown]
# # Feature Scaling Using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
print(x)
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
SM =SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %% [markdown]
# # Modelling

# %% [markdown]
# # Finding the  best  random state

# %%
from sklearn.model_selection import train_test_split
from  sklearn.ensemble import RandomForestClassifier
from sklearn .metrics import accuracy_score
maxAccu = 0
maxRS =0
for i in range (1,2):
    x_train, x_test,y_train ,y_test = train_test_split(x1 , y1, test_size =0.30,random_state =25)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred =RFR.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0 at random_state 1

# %%
x_train, x_test,y_train ,y_test = train_test_split(x1 , y1, test_size =0.30,random_state =maxRS)

# %% [markdown]
# # Classification Alogithrms

# %%
from  sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from  sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve ,accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Random Forest Classifier

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score (y_test,predRFC))
print (confusion_matrix(y_test,predRFC))
print (classification_report(y_test,predRFC))
# Out:
# 0.9124087591240876
# [[19  1  2  0  0  0]
#  [ 2 14  1  1  0  0]
#  [ 1  0 22  0  0  0]
#  [ 0  0  0 29  0  0]
#  [ 0  0  0  0 18  0]
#  [ 1  1  0  2  0 23]]
#               precision    recall  f1-score   support
#
#            1       0.83      0.86      0.84        22
#            2       0.88      0.78      0.82        18
#            3       0.88      0.96      0.92        23
#            5       0.91      1.00      0.95        29
#            6       1.00      1.00      1.00        18
#            7       1.00      0.85      0.92        27
#
#     accuracy                           0.91       137
#    macro avg       0.91      0.91      0.91       137
# weighted avg       0.92      0.91      0.91       137

# %% [markdown]
# ###### The accuracy of Random forest model is 91%

# %% [markdown]
# # Logistic Regression

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
print(accuracy_score (y_test,predLR))
print (confusion_matrix(y_test,predLR))
print (classification_report(y_test,predLR))
# Out:
# 0.7883211678832117
# [[17  1  4  0  0  0]
#  [ 5  7  4  2  0  0]
#  [ 3  5 15  0  0  0]
#  [ 0  0  0 29  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  3  0  2  0 22]]
#               precision    recall  f1-score   support
#
#            1       0.68      0.77      0.72        22
#            2       0.44      0.39      0.41        18
#            3       0.65      0.65      0.65        23
#            5       0.88      1.00      0.94        29
#            6       1.00      1.00      1.00        18
#            7       1.00      0.81      0.90        27
#
#     accuracy                           0.79       137
#    macro avg       0.77      0.77      0.77       137
# weighted avg       0.79      0.79      0.79       137

# %% [markdown]
# ###### The accuracy of Random forest model is 78 %

# %% [markdown]
# # Support Vector Machine Classifier

# %%
svc= SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score (y_test,predsvc))
print (confusion_matrix(y_test,predsvc))
print (classification_report(y_test,predsvc))
# Out:
# 0.8102189781021898
# [[16  1  5  0  0  0]
#  [ 3 11  4  0  0  0]
#  [ 1  5 17  0  0  0]
#  [ 0  3  0 26  0  0]
#  [ 0  0  0  0 18  0]
#  [ 2  0  0  2  0 23]]
#               precision    recall  f1-score   support
#
#            1       0.73      0.73      0.73        22
#            2       0.55      0.61      0.58        18
#            3       0.65      0.74      0.69        23
#            5       0.93      0.90      0.91        29
#            6       1.00      1.00      1.00        18
#            7       1.00      0.85      0.92        27
#
#     accuracy                           0.81       137
#    macro avg       0.81      0.80      0.81       137
# weighted avg       0.82      0.81      0.82       137

# %% [markdown]
# ###### The accuracy of support vector machine classifier model is 81%

# %% [markdown]
# # Gradient Boosting Classifier

# %%
GB= GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score (y_test,predGB))
print (confusion_matrix(y_test,predGB))
print (classification_report(y_test,predGB))
# Out:
# 0.8759124087591241
# [[17  1  3  0  0  1]
#  [ 1 14  1  0  0  2]
#  [ 4  0 19  0  0  0]
#  [ 0  0  0 29  0  0]
#  [ 0  0  0  0 18  0]
#  [ 1  2  0  1  0 23]]
#               precision    recall  f1-score   support
#
#            1       0.74      0.77      0.76        22
#            2       0.82      0.78      0.80        18
#            3       0.83      0.83      0.83        23
#            5       0.97      1.00      0.98        29
#            6       1.00      1.00      1.00        18
#            7       0.88      0.85      0.87        27
#
#     accuracy                           0.88       137
#    macro avg       0.87      0.87      0.87       137
# weighted avg       0.88      0.88      0.88       137

# %% [markdown]
# ###### The accuracy of Gradient Boosting Classifier is 87%

# %% [markdown]
# # Ada Boost Classifier

# %%
ABC= AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC = ABC.predict(x_test)
print(accuracy_score (y_test,predABC))
print (confusion_matrix(y_test,predABC))
print (classification_report(y_test,predABC))
# Out:
# 0.40875912408759124
# [[ 0 21  0  0  0  1]
#  [ 0 15  0  1  0  2]
#  [ 0 21  0  0  0  2]
#  [ 0  0  0  0 22  7]
#  [ 0  0  0  0 18  0]
#  [ 0  2  0  1  1 23]]
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        22
#            2       0.25      0.83      0.39        18
#            3       0.00      0.00      0.00        23
#            5       0.00      0.00      0.00        29
#            6       0.44      1.00      0.61        18
#            7       0.66      0.85      0.74        27
#
#     accuracy                           0.41       137
#    macro avg       0.23      0.45      0.29       137
# weighted avg       0.22      0.41      0.28       137

# %% [markdown]
# ###### The accuracy of Ada Boost Classifier is 40%

# %% [markdown]
# # BaggingClassifier

# %%
BC= BaggingClassifier()
BC.fit(x_train,y_train)
predBC = BC.predict(x_test)
print(accuracy_score (y_test,predBC))
print (confusion_matrix(y_test,predBC))
print (classification_report(y_test,predBC))
# Out:
# 0.8759124087591241
# [[17  3  2  0  0  0]
#  [ 5 11  0  2  0  0]
#  [ 1  0 22  0  0  0]
#  [ 0  0  0 29  0  0]
#  [ 0  0  0  0 18  0]
#  [ 1  0  1  2  0 23]]
#               precision    recall  f1-score   support
#
#            1       0.71      0.77      0.74        22
#            2       0.79      0.61      0.69        18
#            3       0.88      0.96      0.92        23
#            5       0.88      1.00      0.94        29
#            6       1.00      1.00      1.00        18
#            7       1.00      0.85      0.92        27
#
#     accuracy                           0.88       137
#    macro avg       0.88      0.87      0.87       137
# weighted avg       0.88      0.88      0.87       137

# %% [markdown]
# ###### The accuracy of Bagging Classifier is 87%

# %% [markdown]
# # Extra Trees Classifier

# %%
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET = ET.predict(x_test)
print(accuracy_score (y_test,predET))
print (confusion_matrix(y_test,predET))
print (classification_report(y_test,predET))
# Out:
# 0.9124087591240876
# [[19  2  1  0  0  0]
#  [ 2 13  2  1  0  0]
#  [ 2  0 21  0  0  0]
#  [ 0  0  0 29  0  0]
#  [ 0  0  0  0 18  0]
#  [ 0  0  0  2  0 25]]
#               precision    recall  f1-score   support
#
#            1       0.83      0.86      0.84        22
#            2       0.87      0.72      0.79        18
#            3       0.88      0.91      0.89        23
#            5       0.91      1.00      0.95        29
#            6       1.00      1.00      1.00        18
#            7       1.00      0.93      0.96        27
#
#     accuracy                           0.91       137
#    macro avg       0.91      0.90      0.91       137
# weighted avg       0.91      0.91      0.91       137

# %% [markdown]
# ###### The accuracy of ExtraTreesClassifier is 91%

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(RFC,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.93478261 0.85714286 0.82417582 0.89010989 0.92307692]
# 0.8858576206402293
# Difference Between Accuracy and Cross Validation Score is_ 0.02655113848385826

# %%
# checking crosss validation score for Logistic Regression
score = cross_val_score(LR,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.7826087  0.76923077 0.78021978 0.79120879 0.8021978 ]
# 0.7850931677018634
# Difference Between Accuracy and Cross Validation Score is_ 0.0032280001813482784

# %%
# checking crosss validation score for support vector machine classifier
score = cross_val_score(svc,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.81521739 0.81318681 0.75824176 0.8021978  0.85714286]
# 0.8091973244147157
# Difference Between Accuracy and Cross Validation Score is_ 0.001021653687474089

# %%
# checking crosss validation score for Ada Boost Classifier
score = cross_val_score(ABC,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predABC)-score.mean())
# Out:
# [0.38043478 0.32967033 0.38461538 0.59340659 0.51648352]
# 0.44092212135690395
# Difference Between Accuracy and Cross Validation Score is_ -0.03216299726931271

# %%
# checking crosss validation score for Bagging Classifier
score = cross_val_score(BC,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predBC)-score.mean())
# Out:
# [0.83695652 0.78021978 0.79120879 0.79120879 0.87912088]
# 0.8157429526994744
# Difference Between Accuracy and Cross Validation Score is_ 0.06016945605964974

# %%
# checking crosss validation score for GradientBoosting Classifier
score = cross_val_score(GB,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.85869565 0.8021978  0.84615385 0.86813187 0.84615385]
# 0.8442666029622551
# Difference Between Accuracy and Cross Validation Score is_ 0.03164580579686904

# %%
# checking crosss validation score for Extra Trees Classifier
score = cross_val_score(ET,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.94565217 0.86813187 0.82417582 0.91208791 0.91208791]
# 0.8924271380793118
# Difference Between Accuracy and Cross Validation Score is_ 0.019981621044775744

# %% [markdown]
# ###### The random forest classifier and Extra Trees classifier give us good accuracy

# %% [markdown]
# ###### Extra tree classifier model is best model with 94% accuracy

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'criterion':['gini','entropy'],
               'random_state':[10,50,100],
             'max_depth':[0,10,20],
             'n_jobs':[-2,-1,-1],
             'n_estimators':[25,50,100,200]}

# %%
GCV =GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [25, 50, 100, 200],
#                          'n_jobs': [-2, -1, -1],
#                          'random_state': [10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 200,
#  'n_jobs': -2,
#  'random_state': 100}

# %%
Final_model = ExtraTreesClassifier(criterion ='entropy', max_depth =20, n_estimators=200,n_jobs =-2,random_state= 100)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print (acc*100)
# Out:
# 86.13138686131386

# %% [markdown]
# # Saving The Model

# %%
import joblib
joblib.dump(Final_model,"Glass Identification.pkl")
# Out:
# ['Glass Identification.pkl']

# %% [markdown]
# # Predicting The Save Model

# %%
# lets load the save model and predict it 
model =joblib.load("Glass Identification.pkl")
prediction = model.predict(x_test)
prediction
# Out:
# array([1, 3, 5, 3, 3, 6, 6, 7, 7, 2, 5, 6, 5, 7, 1, 5, 2, 5, 7, 6, 1, 7,
#        5, 1, 3, 7, 3, 3, 7, 1, 2, 2, 6, 3, 5, 7, 1, 1, 1, 2, 1, 3, 5, 3,
#        6, 5, 2, 5, 6, 1, 5, 7, 3, 5, 7, 2, 7, 3, 5, 5, 2, 3, 5, 6, 3, 6,
#        5, 6, 3, 5, 7, 5, 1, 6, 7, 5, 7, 7, 6, 7, 1, 1, 6, 2, 2, 5, 7, 3,
#        6, 1, 1, 3, 6, 5, 5, 3, 7, 5, 2, 1, 3, 3, 2, 6, 2, 7, 3, 7, 3, 2,
#        5, 7, 5, 5, 3, 1, 2, 2, 7, 5, 2, 5, 6, 5, 7, 1, 7, 6, 3, 2, 1, 1,
#        1, 3, 1, 5, 5], dtype=int64)

# %%
a = np.array(y_test)
df = pd.DataFrame()
df["predicted"] = prediction
df["original"] = a
df
# Out:
#      predicted  original
# 0            1         1
# 1            3         3
# 2            5         5
# 3            3         3
# 4            3         3
# ..         ...       ...
# 132          1         1
# 133          3         3
# 134          1         1
# 135          5         7
# 136          5         5
#
# [137 rows x 2 columns]

# %% [markdown]
# ###### Here the original value and predicted value is same means prediction is correct and if it is not same then prediction is wrong.
